# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv('../Datasets/Boston/train.csv')
test_df = pd.read_csv('../Datasets/Boston/test.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_df['SalePrice'] = -1234

# %%
#feature engineering process1 
#Remove all the null and missing values and convert string to numerical and continue
#finding all the missing values in rows and remove

train_df = train_df.dropna(axis=1,how='all')
df = pd.concat((train_df, test_df), axis = 0)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
#feature engineering process1 
#Remove all the null and missing values and convert string to numerical and continue
#finding all the missing cols
df.columns[df.isnull().any()]
# Out:
# Index(['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Electrical', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType'],
#       dtype='object')

# %%
df[df.SalePrice != -1234].columns.isnull().any()
# Out:
# False

# %%
df.loc[:, df.dtypes == object].count()
# Out:
# MSZoning         2915
# Street           2919
# Alley             198
# LotShape         2919
# LandContour      2919
# Utilities        2917
# LotConfig        2919
# LandSlope        2919
# Neighborhood     2919
# Condition1       2919
# Condition2       2919
# BldgType         2919
# HouseStyle       2919
# RoofStyle        2919
# RoofMatl         2919
# Exterior1st      2918
# Exterior2nd      2918
# MasVnrType       2895
# ExterQual        2919
# ExterCond        2919
# Foundation       2919
# BsmtQual         2838
# BsmtCond         2837
# BsmtExposure     2837
# BsmtFinType1     2840
# BsmtFinType2     2839
# Heating          2919
# HeatingQC        2919
# CentralAir       2919
# Electrical       2918
# KitchenQual      2918
# Functional       2917
# FireplaceQu      1499
# GarageType       2762
# GarageFinish     2760
# GarageQual       2760
# GarageCond       2760
# PavedDrive       2919
# PoolQC             10
# Fence             571
# MiscFeature       105
# ...

# %%
for i in df.loc[:, df.dtypes == object]:
    print(df[i].unique())
    freq_map = df[i].value_counts().to_dict()
    print(freq_map)
    df[i] = df[i].map(freq_map)
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH' nan]
# {'RL': 2265, 'RM': 460, 'FV': 139, 'RH': 26, 'C (all)': 25}
# ['Pave' 'Grvl']
# {'Pave': 2907, 'Grvl': 12}
# [nan 'Grvl' 'Pave']
# {'Grvl': 120, 'Pave': 78}
# ['Reg' 'IR1' 'IR2' 'IR3']
# {'Reg': 1859, 'IR1': 968, 'IR2': 76, 'IR3': 16}
# ['Lvl' 'Bnk' 'Low' 'HLS']
# {'Lvl': 2622, 'HLS': 120, 'Bnk': 117, 'Low': 60}
# ['AllPub' 'NoSeWa' nan]
# {'AllPub': 2916, 'NoSeWa': 1}
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# {'Inside': 2133, 'Corner': 511, 'CulDSac': 176, 'FR2': 85, 'FR3': 14}
# ['Gtl' 'Mod' 'Sev']
# {'Gtl': 2778, 'Mod': 125, 'Sev': 16}
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# ...

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60    2265.0         65.0     8450    2907    NaN
# 1        2          20    2265.0         80.0     9600    2907    NaN
# 2        3          60    2265.0         68.0    11250    2907    NaN
# 3        4          70    2265.0         60.0     9550    2907    NaN
# 4        5          60    2265.0         84.0    14260    2907    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1454  2915         160     460.0         21.0     1936    2907    NaN
# 1455  2916         160     460.0         21.0     1894    2907    NaN
# 1456  2917          20    2265.0        160.0    20000    2907    NaN
# 1457  2918          85    2265.0         62.0    10441    2907    NaN
# 1458  2919          60    2265.0         74.0     9627    2907    NaN
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df.drop(["Alley", "PoolQC", "Fence", "MiscFeature"], inplace = True, axis = 1)

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60    2265.0         65.0     8450    2907      1859
# 1        2          20    2265.0         80.0     9600    2907      1859
# 2        3          60    2265.0         68.0    11250    2907       968
# 3        4          70    2265.0         60.0     9550    2907       968
# 4        5          60    2265.0         84.0    14260    2907       968
# ...    ...         ...       ...          ...      ...     ...       ...
# 1454  2915         160     460.0         21.0     1936    2907      1859
# 1455  2916         160     460.0         21.0     1894    2907      1859
# 1456  2917          20    2265.0        160.0    20000    2907      1859
# 1457  2918          85    2265.0         62.0    10441    2907      1859
# 1458  2919          60    2265.0         74.0     9627    2907      1859
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
Train = df[df.SalePrice != -1234]

# %%
Train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60    2265.0         65.0     8450    2907      1859
# 1        2          20    2265.0         80.0     9600    2907      1859
# 2        3          60    2265.0         68.0    11250    2907       968
# 3        4          70    2265.0         60.0     9550    2907       968
# 4        5          60    2265.0         84.0    14260    2907       968
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60    2265.0         62.0     7917    2907      1859
# 1456  1457          20    2265.0         85.0    13175    2907      1859
# 1457  1458          70    2265.0         66.0     9042    2907      1859
# 1458  1459          20    2265.0         68.0     9717    2907      1859
# 1459  1460          20    2265.0         75.0     9937    2907      1859
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
Test = df[df.SalePrice == -1234]

# %%
Test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     1461          20      26.0         80.0    11622    2907      1859
# 1     1462          20    2265.0         81.0    14267    2907       968
# 2     1463          60    2265.0         74.0    13830    2907       968
# 3     1464          60    2265.0         78.0     9978    2907       968
# 4     1465         120    2265.0         43.0     5005    2907       968
# ...    ...         ...       ...          ...      ...     ...       ...
# 1454  2915         160     460.0         21.0     1936    2907      1859
# 1455  2916         160     460.0         21.0     1894    2907      1859
# 1456  2917          20    2265.0        160.0    20000    2907      1859
# 1457  2918          85    2265.0         62.0    10441    2907      1859
# 1458  2919          60    2265.0         74.0     9627    2907      1859
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
Features = Train.iloc[:,:-1]

# %%
labels = Train.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(Features, labels, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (1168, 76)

# %%
y_train.shape
# Out:
# (1168,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.dummy import DummyClassifier

# %%
dummy_model = DummyClassifier(strategy="most_frequent")
dummy_model.fit(X_train, y_train)
dummy_model.score(X_test, y_test)
# Out:
# 0.017123287671232876

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
regressor.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-c354f913fbe1> in <module>
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(X_train, y_train)
#       3 regressor.score(X_test,y_test)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
